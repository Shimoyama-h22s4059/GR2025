# %% [markdown]
# # 埋め込みの平均ベクトルでTransformerを学習＆5分割交差検証
# - モデル：`esm-1b`

# %% [markdown]
# ## 1. 必要ライブラリのインポート

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import numpy as np

model_name = "esm1b"

# %% [markdown]
# ### 1.1 データセットの作成

# %%
class MeanEmbeddingDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.long)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx].unsqueeze(0), self.y[idx]

# %% [markdown]
# ### 1.2 Transformer分類モデル

# %%
import torch.nn

class MeanEmbeddingTransformerClassifier(nn.Module):
    def __init__(self, input_dim=1280, hidden_dim=512, num_classes=5, num_heads=8, num_layers=2, dropout=0.1):
        super().__init__()
        self.linear_proj = nn.Linear(input_dim, hidden_dim)
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=hidden_dim, nhead=num_heads, batch_first=True, dropout=dropout
        )
        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
        self.fc = nn.Linear(hidden_dim, num_classes)

    def forward(self, x):
        x = self.linear_proj(x)
        x = self.transformer(x)
        x = x.mean(dim=1)
        return self.fc(x)

# %% [markdown]
# ## 2. データ読み込み

# %%
X = np.load(f"../data/embedding-vectors/{model_name}/mean_vectors.npy")
y = np.load(f"../data/embedding-vectors/{model_name}/labels.npy")

print("X.shape:", X.shape)
print("y.shape:", y.shape)
# Out:
# X.shape: (7716, 1280)
# y.shape: (7716,)

# %% [markdown]
# ## 3. 学習と評価（5分割交差検証）

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
import torch.optim as optim

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)  # 5分割交差検証

accuracies, precisions, recalls, f1_scores = [], [], [], []

# %%
for fold, (train_idx, val_idx) in enumerate(skf.split(X, y), 1):
    print(f"\033[34m[Fold {fold} / 5]\033[0m")

    train_ds = MeanEmbeddingDataset(X[train_idx], y[train_idx])
    val_ds = MeanEmbeddingDataset(X[val_idx], y[val_idx])

    train_loader = DataLoader(train_ds, batch_size=32, shuffle=True)
    val_loader = DataLoader(val_ds, batch_size=32)

    model = MeanEmbeddingTransformerClassifier().to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=1e-4)

    # --- 学習ループ ---
    for epoch in range(100):  # 調整可能
        model.train()
        total_loss = 0

        for xb, yb in train_loader:
            xb, yb = xb.to(device), yb.to(device)
            optimizer.zero_grad()
            out = model(xb)
            loss = criterion(out, yb)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        print(f"\033[36mEpoch {epoch + 1}, loss={total_loss/len(train_loader):.6f}\033[0m")

    # --- 評価 ---
    model.eval()
    y_true, y_pred = [], []

    with torch.no_grad():
        for xb, yb in val_loader:
            xb = xb.to(device)
            out = model(xb)
            preds = out.argmax(dim=1).cpu().numpy()
            y_pred.extend(preds)
            y_true.extend(yb.numpy())

    # --- 指標の計算 ---
    acc = accuracy_score(y_true, y_pred)
    prec = precision_score(y_true, y_pred, average="macro", zero_division=0)
    rec = recall_score(y_true, y_pred, average="macro", zero_division=0)
    f1 = f1_score(y_true, y_pred, average="macro")
    cm = confusion_matrix(y_true, y_pred)

    # --- 保存 ---
    accuracies.append(acc)
    precisions.append(prec)
    recalls.append(rec)
    f1_scores.append(f1)

    # --- 出力 ---
    print(f"\n\033[32mFold {fold} result:\033[0m")
    print(f"\033[92mAccuracy : {acc:.4f}\033[0m")
    print(f"\033[92mPrecision: {prec:.4f}\033[0m")
    print(f"\033[92mRecall   : {rec:.4f}\033[0m")
    print(f"\033[92mF1-score : {f1:.4f}\033[0m")
    print("\nConfusion Matrix:")
    print(cm)
    print("\nClassification Report:")
    print(classification_report(y_true, y_pred, zero_division=0, digits=4))

# === 平均結果 ===
print("\n\033[35m===== Cross-validation Summary =====\033[0m")
print(f"\033[95mMean Accuracy : {np.mean(accuracies):.4f} ± {np.std(accuracies):.4f}\033[0m")
print(f"\033[95mMean Precision: {np.mean(precisions):.4f} ± {np.std(precisions):.4f}\033[0m")
print(f"\033[95mMean Recall   : {np.mean(recalls):.4f} ± {np.std(recalls):.4f}\033[0m")
print(f"\033[95mMean F1-score : {np.mean(f1_scores):.4f} ± {np.std(f1_scores):.4f}\033[0m")
# Out:
# [Fold 1 / 5]
# Epoch 1, loss=0.628083
# Epoch 2, loss=0.525113
# Epoch 3, loss=0.469092
# Epoch 4, loss=0.438745
# Epoch 5, loss=0.416497
# Epoch 6, loss=0.402829
# Epoch 7, loss=0.390583
# Epoch 8, loss=0.384477
# Epoch 9, loss=0.375306
# Epoch 10, loss=0.362399
# Epoch 11, loss=0.357400
# Epoch 12, loss=0.348400
# Epoch 13, loss=0.354061
# Epoch 14, loss=0.349008
# Epoch 15, loss=0.354256
# Epoch 16, loss=0.340877
# Epoch 17, loss=0.338864
# Epoch 18, loss=0.341516
# Epoch 19, loss=0.333615
# Epoch 20, loss=0.331966
# Epoch 21, loss=0.334277
# Epoch 22, loss=0.326300
# Epoch 23, loss=0.327467
# Epoch 24, loss=0.329794
# Epoch 25, loss=0.323503
# Epoch 26, loss=0.316613
# Epoch 27, loss=0.317687
# Epoch 28, loss=0.315356
# Epoch 29, loss=0.318013
# Epoch 30, loss=0.318293
# Epoch 31, loss=0.316290
# Epoch 32, loss=0.310903
# Epoch 33, loss=0.314395
# Epoch 34, loss=0.311149
# Epoch 35, loss=0.308673
# Epoch 36, loss=0.314208
# Epoch 37, loss=0.315705
# Epoch 38, loss=0.308748
# Epoch 39, loss=0.312220
# Epoch 40, loss=0.307328
# Epoch 41, loss=0.305203
# Epoch 42, loss=0.304368
# Epoch 43, loss=0.304346
# Epoch 44, loss=0.309357
# Epoch 45, loss=0.298179
# Epoch 46, loss=0.296933
# Epoch 47, loss=0.296573
# Epoch 48, loss=0.304782
# Epoch 49, loss=0.297762
# Epoch 50, loss=0.296762
# Epoch 51, loss=0.301019
# Epoch 52, loss=0.295544
# Epoch 53, loss=0.294608
# Epoch 54, loss=0.294518
# Epoch 55, loss=0.304762
# Epoch 56, loss=0.289740
# Epoch 57, loss=0.291318
# Epoch 58, loss=0.290215
# Epoch 59, loss=0.294502
# Epoch 60, loss=0.288123
# Epoch 61, loss=0.293114
# Epoch 62, loss=0.308998
# Epoch 63, loss=0.288993
# Epoch 64, loss=0.289519
# Epoch 65, loss=0.293239
# Epoch 66, loss=0.287056
# Epoch 67, loss=0.289184
# Epoch 68, loss=0.288748
# Epoch 69, loss=0.281517
# Epoch 70, loss=0.284985
# Epoch 71, loss=0.286717
# Epoch 72, loss=0.292537
# Epoch 73, loss=0.283295
# Epoch 74, loss=0.288281
# Epoch 75, loss=0.286459
# Epoch 76, loss=0.286766
# Epoch 77, loss=0.284785
# Epoch 78, loss=0.279910
# Epoch 79, loss=0.281760
# Epoch 80, loss=0.281385
# Epoch 81, loss=0.288560
# Epoch 82, loss=0.284117
# Epoch 83, loss=0.283648
# Epoch 84, loss=0.285031
# Epoch 85, loss=0.280237
# Epoch 86, loss=0.286050
# Epoch 87, loss=0.292290
# Epoch 88, loss=0.275648
# Epoch 89, loss=0.277663
# Epoch 90, loss=0.279896
# Epoch 91, loss=0.280072
# Epoch 92, loss=0.282689
# Epoch 93, loss=0.287005
# Epoch 94, loss=0.282235
# Epoch 95, loss=0.278407
# Epoch 96, loss=0.275993
# Epoch 97, loss=0.272848
# Epoch 98, loss=0.272394
# Epoch 99, loss=0.273779
# Epoch 100, loss=0.275528
#
# Fold 1 result:
# Accuracy : 0.8394
# Precision: 0.4492
# Recall   : 0.3909
# F1-score : 0.3971
#
# Confusion Matrix:
# [[943  11 107   0   0]
#  [ 59  18  14   0   0]
#  [ 51   0 335   0   0]
#  [  3   0   0   0   0]
#  [  3   0   0   0   0]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.89      0.89      1061
#            1       0.62      0.20      0.30        91
#            2       0.73      0.87      0.80       386
#            3       0.00      0.00      0.00         3
#            4       0.00      0.00      0.00         3
#
#     accuracy                           0.84      1544
#    macro avg       0.45      0.39      0.40      1544
# weighted avg       0.83      0.84      0.83      1544
#
# [Fold 2 / 5]
# Epoch 1, loss=0.624877
# Epoch 2, loss=0.525452
# Epoch 3, loss=0.472651
# Epoch 4, loss=0.425092
# Epoch 5, loss=0.423905
# Epoch 6, loss=0.413928
# Epoch 7, loss=0.386874
# Epoch 8, loss=0.389976
# Epoch 9, loss=0.370738
# Epoch 10, loss=0.372383
# Epoch 11, loss=0.359012
# Epoch 12, loss=0.356026
# Epoch 13, loss=0.354433
# Epoch 14, loss=0.354425
# Epoch 15, loss=0.345999
# Epoch 16, loss=0.344310
# Epoch 17, loss=0.343124
# Epoch 18, loss=0.337902
# Epoch 19, loss=0.340472
# Epoch 20, loss=0.338833
# Epoch 21, loss=0.331022
# Epoch 22, loss=0.334561
# Epoch 23, loss=0.328374
# Epoch 24, loss=0.334689
# Epoch 25, loss=0.330817
# Epoch 26, loss=0.324637
# Epoch 27, loss=0.319495
# Epoch 28, loss=0.335653
# Epoch 29, loss=0.326239
# Epoch 30, loss=0.312881
# Epoch 31, loss=0.326311
# Epoch 32, loss=0.318648
# Epoch 33, loss=0.316626
# Epoch 34, loss=0.312704
# Epoch 35, loss=0.314016
# Epoch 36, loss=0.309934
# Epoch 37, loss=0.311729
# Epoch 38, loss=0.313085
# Epoch 39, loss=0.306618
# Epoch 40, loss=0.315726
# Epoch 41, loss=0.310505
# Epoch 42, loss=0.306579
# Epoch 43, loss=0.313503
# Epoch 44, loss=0.304966
# Epoch 45, loss=0.303331
# Epoch 46, loss=0.308964
# Epoch 47, loss=0.303491
# Epoch 48, loss=0.302365
# Epoch 49, loss=0.302884
# Epoch 50, loss=0.307286
# Epoch 51, loss=0.303918
# Epoch 52, loss=0.302841
# Epoch 53, loss=0.298596
# Epoch 54, loss=0.299201
# Epoch 55, loss=0.298369
# Epoch 56, loss=0.297497
# Epoch 57, loss=0.298093
# Epoch 58, loss=0.299737
# Epoch 59, loss=0.302009
# Epoch 60, loss=0.300436
# Epoch 61, loss=0.291881
# Epoch 62, loss=0.298132
# Epoch 63, loss=0.295336
# Epoch 64, loss=0.292753
# Epoch 65, loss=0.291472
# Epoch 66, loss=0.301470
# Epoch 67, loss=0.293181
# Epoch 68, loss=0.292645
# Epoch 69, loss=0.293250
# Epoch 70, loss=0.295659
# Epoch 71, loss=0.297398
# Epoch 72, loss=0.295266
# Epoch 73, loss=0.297798
# Epoch 74, loss=0.298447
# Epoch 75, loss=0.299491
# Epoch 76, loss=0.291622
# Epoch 77, loss=0.294098
# Epoch 78, loss=0.289083
# Epoch 79, loss=0.287881
# Epoch 80, loss=0.288209
# Epoch 81, loss=0.290706
# Epoch 82, loss=0.289399
# Epoch 83, loss=0.286930
# Epoch 84, loss=0.293925
# Epoch 85, loss=0.295023
# Epoch 86, loss=0.285605
# Epoch 87, loss=0.281223
# Epoch 88, loss=0.287086
# Epoch 89, loss=0.284648
# Epoch 90, loss=0.282463
# Epoch 91, loss=0.283565
# Epoch 92, loss=0.284328
# Epoch 93, loss=0.283637
# Epoch 94, loss=0.289795
# Epoch 95, loss=0.283061
# Epoch 96, loss=0.285065
# Epoch 97, loss=0.282554
# Epoch 98, loss=0.277759
# Epoch 99, loss=0.278873
# Epoch 100, loss=0.277561
#
# Fold 2 result:
# Accuracy : 0.8393
# Precision: 0.4524
# Recall   : 0.3914
# F1-score : 0.3938
#
# Confusion Matrix:
# [[931   8 122   0   0]
#  [ 64  16  10   0   0]
#  [ 37   1 348   0   0]
#  [  2   0   0   0   0]
#  [  4   0   0   0   0]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.88      0.89      1061
#            1       0.64      0.18      0.28        90
#            2       0.72      0.90      0.80       386
#            3       0.00      0.00      0.00         2
#            4       0.00      0.00      0.00         4
#
#     accuracy                           0.84      1543
#    macro avg       0.45      0.39      0.39      1543
# weighted avg       0.84      0.84      0.83      1543
#
# [Fold 3 / 5]
# Epoch 1, loss=0.630526
# Epoch 2, loss=0.525346
# Epoch 3, loss=0.465178
# Epoch 4, loss=0.444723
# Epoch 5, loss=0.413751
# Epoch 6, loss=0.408103
# Epoch 7, loss=0.392536
# Epoch 8, loss=0.380246
# Epoch 9, loss=0.383097
# Epoch 10, loss=0.372694
# Epoch 11, loss=0.364395
# Epoch 12, loss=0.358025
# Epoch 13, loss=0.354470
# Epoch 14, loss=0.349862
# Epoch 15, loss=0.346442
# Epoch 16, loss=0.345715
# Epoch 17, loss=0.343571
# Epoch 18, loss=0.339744
# Epoch 19, loss=0.336906
# Epoch 20, loss=0.338065
# Epoch 21, loss=0.335116
# Epoch 22, loss=0.332786
# Epoch 23, loss=0.326030
# Epoch 24, loss=0.327534
# Epoch 25, loss=0.331687
# Epoch 26, loss=0.324735
# Epoch 27, loss=0.325840
# Epoch 28, loss=0.326842
# Epoch 29, loss=0.322833
# Epoch 30, loss=0.315610
# Epoch 31, loss=0.323008
# Epoch 32, loss=0.316886
# Epoch 33, loss=0.322625
# Epoch 34, loss=0.319141
# Epoch 35, loss=0.311015
# Epoch 36, loss=0.316030
# Epoch 37, loss=0.314411
# Epoch 38, loss=0.307063
# Epoch 39, loss=0.308179
# Epoch 40, loss=0.317361
# Epoch 41, loss=0.308425
# Epoch 42, loss=0.307440
# Epoch 43, loss=0.312198
# Epoch 44, loss=0.307083
# Epoch 45, loss=0.318947
# Epoch 46, loss=0.311023
# Epoch 47, loss=0.301658
# Epoch 48, loss=0.304269
# Epoch 49, loss=0.302841
# Epoch 50, loss=0.304122
# Epoch 51, loss=0.300991
# Epoch 52, loss=0.299081
# Epoch 53, loss=0.303630
# Epoch 54, loss=0.299947
# Epoch 55, loss=0.298419
# Epoch 56, loss=0.309284
# Epoch 57, loss=0.298147
# Epoch 58, loss=0.296038
# Epoch 59, loss=0.306283
# Epoch 60, loss=0.296415
# Epoch 61, loss=0.291900
# Epoch 62, loss=0.288994
# Epoch 63, loss=0.295756
# Epoch 64, loss=0.294450
# Epoch 65, loss=0.293433
# Epoch 66, loss=0.295476
# Epoch 67, loss=0.290994
# Epoch 68, loss=0.309398
# Epoch 69, loss=0.293682
# Epoch 70, loss=0.289848
# Epoch 71, loss=0.292611
# Epoch 72, loss=0.296887
# Epoch 73, loss=0.290450
# Epoch 74, loss=0.289488
# Epoch 75, loss=0.290498
# Epoch 76, loss=0.285877
# Epoch 77, loss=0.287147
# Epoch 78, loss=0.293309
# Epoch 79, loss=0.295221
# Epoch 80, loss=0.289680
# Epoch 81, loss=0.289875
# Epoch 82, loss=0.290654
# Epoch 83, loss=0.285957
# Epoch 84, loss=0.286737
# Epoch 85, loss=0.287879
# Epoch 86, loss=0.288857
# Epoch 87, loss=0.285976
# Epoch 88, loss=0.281237
# Epoch 89, loss=0.281057
# Epoch 90, loss=0.282813
# Epoch 91, loss=0.288229
# Epoch 92, loss=0.290818
# Epoch 93, loss=0.284392
# Epoch 94, loss=0.280379
# Epoch 95, loss=0.279500
# Epoch 96, loss=0.283896
# Epoch 97, loss=0.281125
# Epoch 98, loss=0.280150
# Epoch 99, loss=0.285947
# Epoch 100, loss=0.280569
#
# Fold 3 result:
# Accuracy : 0.8445
# Precision: 0.4389
# Recall   : 0.3877
# F1-score : 0.3909
#
# Confusion Matrix:
# [[949  12  99   0   0]
#  [ 58  15  18   0   0]
#  [ 47   0 339   0   0]
#  [  2   0   0   0   0]
#  [  4   0   0   0   0]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90      1060
#            1       0.56      0.16      0.25        91
#            2       0.74      0.88      0.81       386
#            3       0.00      0.00      0.00         2
#            4       0.00      0.00      0.00         4
#
#     accuracy                           0.84      1543
#    macro avg       0.44      0.39      0.39      1543
# weighted avg       0.83      0.84      0.83      1543
#
# [Fold 4 / 5]
# Epoch 1, loss=0.620779
# Epoch 2, loss=0.518997
# Epoch 3, loss=0.459218
# Epoch 4, loss=0.425338
# Epoch 5, loss=0.408477
# Epoch 6, loss=0.401724
# Epoch 7, loss=0.390311
# Epoch 8, loss=0.370243
# Epoch 9, loss=0.374593
# Epoch 10, loss=0.368851
# Epoch 11, loss=0.362349
# Epoch 12, loss=0.355210
# Epoch 13, loss=0.360249
# Epoch 14, loss=0.344983
# Epoch 15, loss=0.347682
# Epoch 16, loss=0.349481
# Epoch 17, loss=0.332630
# Epoch 18, loss=0.335728
# Epoch 19, loss=0.335311
# Epoch 20, loss=0.345085
# Epoch 21, loss=0.328657
# Epoch 22, loss=0.336977
# Epoch 23, loss=0.327417
# Epoch 24, loss=0.324606
# Epoch 25, loss=0.320264
# Epoch 26, loss=0.323748
# Epoch 27, loss=0.320793
# Epoch 28, loss=0.318229
# Epoch 29, loss=0.320285
# Epoch 30, loss=0.318952
# Epoch 31, loss=0.317030
# Epoch 32, loss=0.315495
# Epoch 33, loss=0.311492
# Epoch 34, loss=0.313043
# Epoch 35, loss=0.312445
# Epoch 36, loss=0.309563
# Epoch 37, loss=0.309145
# Epoch 38, loss=0.306857
# Epoch 39, loss=0.315485
# Epoch 40, loss=0.302640
# Epoch 41, loss=0.305952
# Epoch 42, loss=0.311362
# Epoch 43, loss=0.303556
# Epoch 44, loss=0.303452
# Epoch 45, loss=0.309391
# Epoch 46, loss=0.301447
# Epoch 47, loss=0.306604
# Epoch 48, loss=0.299792
# Epoch 49, loss=0.300040
# Epoch 50, loss=0.299954
# Epoch 51, loss=0.299881
# Epoch 52, loss=0.301693
# Epoch 53, loss=0.293100
# Epoch 54, loss=0.301899
# Epoch 55, loss=0.291358
# Epoch 56, loss=0.295692
# Epoch 57, loss=0.293902
# Epoch 58, loss=0.293632
# Epoch 59, loss=0.292895
# Epoch 60, loss=0.298442
# Epoch 61, loss=0.300334
# Epoch 62, loss=0.289626
# Epoch 63, loss=0.291709
# Epoch 64, loss=0.291076
# Epoch 65, loss=0.294215
# Epoch 66, loss=0.289658
# Epoch 67, loss=0.288005
# Epoch 68, loss=0.295541
# Epoch 69, loss=0.290657
# Epoch 70, loss=0.289739
# Epoch 71, loss=0.294847
# Epoch 72, loss=0.290974
# Epoch 73, loss=0.285629
# Epoch 74, loss=0.283154
# Epoch 75, loss=0.281525
# Epoch 76, loss=0.284927
# Epoch 77, loss=0.282354
# Epoch 78, loss=0.285793
# Epoch 79, loss=0.288830
# Epoch 80, loss=0.287396
# Epoch 81, loss=0.285449
# Epoch 82, loss=0.291291
# Epoch 83, loss=0.286994
# Epoch 84, loss=0.283548
# Epoch 85, loss=0.283783
# Epoch 86, loss=0.283327
# Epoch 87, loss=0.283167
# Epoch 88, loss=0.284256
# Epoch 89, loss=0.296578
# Epoch 90, loss=0.281059
# Epoch 91, loss=0.284774
# Epoch 92, loss=0.281201
# Epoch 93, loss=0.277803
# Epoch 94, loss=0.279712
# Epoch 95, loss=0.284977
# Epoch 96, loss=0.276472
# Epoch 97, loss=0.285798
# Epoch 98, loss=0.278754
# Epoch 99, loss=0.286118
# Epoch 100, loss=0.278596
#
# Fold 4 result:
# Accuracy : 0.8270
# Precision: 0.5059
# Recall   : 0.3447
# F1-score : 0.3737
#
# Confusion Matrix:
# [[1043    2   14    0    1]
#  [  57   16   18    0    0]
#  [ 167    1  217    0    0]
#  [   2    0    1    0    0]
#  [   4    0    0    0    0]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.98      0.89      1060
#            1       0.84      0.18      0.29        91
#            2       0.87      0.56      0.68       385
#            3       0.00      0.00      0.00         3
#            4       0.00      0.00      0.00         4
#
#     accuracy                           0.83      1543
#    macro avg       0.51      0.34      0.37      1543
# weighted avg       0.83      0.83      0.80      1543
#
# [Fold 5 / 5]
# Epoch 1, loss=0.625028
# Epoch 2, loss=0.512554
# Epoch 3, loss=0.458650
# Epoch 4, loss=0.432002
# Epoch 5, loss=0.411144
# Epoch 6, loss=0.391496
# Epoch 7, loss=0.383993
# Epoch 8, loss=0.377460
# Epoch 9, loss=0.368571
# Epoch 10, loss=0.364492
# Epoch 11, loss=0.352045
# Epoch 12, loss=0.355715
# Epoch 13, loss=0.349476
# Epoch 14, loss=0.348227
# Epoch 15, loss=0.344398
# Epoch 16, loss=0.340527
# Epoch 17, loss=0.338949
# Epoch 18, loss=0.338135
# Epoch 19, loss=0.333401
# Epoch 20, loss=0.331507
# Epoch 21, loss=0.326677
# Epoch 22, loss=0.330033
# Epoch 23, loss=0.320575
# Epoch 24, loss=0.321098
# Epoch 25, loss=0.319145
# Epoch 26, loss=0.317405
# Epoch 27, loss=0.319845
# Epoch 28, loss=0.316838
# Epoch 29, loss=0.325167
# Epoch 30, loss=0.320141
# Epoch 31, loss=0.311617
# Epoch 32, loss=0.320864
# Epoch 33, loss=0.306415
# Epoch 34, loss=0.305899
# Epoch 35, loss=0.315097
# Epoch 36, loss=0.313518
# Epoch 37, loss=0.310561
# Epoch 38, loss=0.303598
# Epoch 39, loss=0.305806
# Epoch 40, loss=0.301212
# Epoch 41, loss=0.303439
# Epoch 42, loss=0.308829
# Epoch 43, loss=0.302902
# Epoch 44, loss=0.306020
# Epoch 45, loss=0.301427
# Epoch 46, loss=0.300624
# Epoch 47, loss=0.302084
# Epoch 48, loss=0.302982
# Epoch 49, loss=0.299642
# Epoch 50, loss=0.299196
# Epoch 51, loss=0.299924
# Epoch 52, loss=0.298275
# Epoch 53, loss=0.294414
# Epoch 54, loss=0.296605
# Epoch 55, loss=0.291648
# Epoch 56, loss=0.295866
# Epoch 57, loss=0.298574
# Epoch 58, loss=0.303128
# Epoch 59, loss=0.294369
# Epoch 60, loss=0.294157
# Epoch 61, loss=0.293623
# Epoch 62, loss=0.294979
# Epoch 63, loss=0.296503
# Epoch 64, loss=0.290191
# Epoch 65, loss=0.291311
# Epoch 66, loss=0.286528
# Epoch 67, loss=0.284477
# Epoch 68, loss=0.290426
# Epoch 69, loss=0.287571
# Epoch 70, loss=0.288309
# Epoch 71, loss=0.293965
# Epoch 72, loss=0.289869
# Epoch 73, loss=0.287653
# Epoch 74, loss=0.290993
# Epoch 75, loss=0.288643
# Epoch 76, loss=0.288139
# Epoch 77, loss=0.286808
# Epoch 78, loss=0.284186
# Epoch 79, loss=0.296711
# Epoch 80, loss=0.289385
# Epoch 81, loss=0.282496
# Epoch 82, loss=0.283431
# Epoch 83, loss=0.281257
# Epoch 84, loss=0.287007
# Epoch 85, loss=0.282184
# Epoch 86, loss=0.280405
# Epoch 87, loss=0.279937
# Epoch 88, loss=0.278548
# Epoch 89, loss=0.293081
# Epoch 90, loss=0.279639
# Epoch 91, loss=0.280809
# Epoch 92, loss=0.284438
# Epoch 93, loss=0.283402
# Epoch 94, loss=0.276582
# Epoch 95, loss=0.277575
# Epoch 96, loss=0.285098
# Epoch 97, loss=0.278531
# Epoch 98, loss=0.285368
# Epoch 99, loss=0.274641
# Epoch 100, loss=0.281854
#
# Fold 5 result:
# Accuracy : 0.8308
# Precision: 0.5030
# Recall   : 0.3724
# F1-score : 0.3756
#
# Confusion Matrix:
# [[942   1 117   0   0]
#  [ 71  11   9   0   0]
#  [ 57   0 329   0   0]
#  [  3   0   0   0   0]
#  [  3   0   0   0   0]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.89      0.88      1060
#            1       0.92      0.12      0.21        91
#            2       0.72      0.85      0.78       386
#            3       0.00      0.00      0.00         3
#            4       0.00      0.00      0.00         3
#
#     accuracy                           0.83      1543
#    macro avg       0.50      0.37      0.38      1543
# weighted avg       0.84      0.83      0.81      1543
#
#
# ===== Cross-validation Summary =====
# Mean Accuracy : 0.8362 ± 0.0064
# Mean Precision: 0.4699 ± 0.0286
# Mean Recall   : 0.3774 ± 0.0178
# Mean F1-score : 0.3862 ± 0.0097

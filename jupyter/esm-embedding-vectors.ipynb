# %%
import matplotlib.pyplot as plt

cmap = plt.get_cmap("gist_rainbow")

amino_vec = {
    "A": {"x":  -8.68695689, "y": 17.59750170},
    "C": {"x": -43.97738151, "y":  7.75439890},
    "D": {"x":  32.04283369, "y": 18.36922320},
    "E": {"x":  -6.53400766, "y":  3.48291763},
    "F": {"x": -29.43734320, "y": 13.24152334},
    "G": {"x": -27.56498378, "y": 34.97121236},
    "H": {"x":   5.36355594, "y": 10.43069579},
    "I": {"x": -47.04540132, "y": 19.51081186},
    "K": {"x":  22.48004700, "y": 76.51622031},
    "L": {"x": -25.70859743, "y":  7.31849861},
    "M": {"x":  19.68051122, "y":  3.47020512},
    "N": {"x":  38.13948836, "y": 28.64883712},
    "P": {"x":  40.04005664, "y": 17.69305484},
    "Q": {"x":  69.80535921, "y": 29.29943250},
    "R": {"x":  16.94420936, "y": 76.62714202},
    "S": {"x":  60.99613090, "y": 29.01551450},
    "T": {"x": -18.90118486, "y": 13.53637820},
    "V": {"x": -36.19350723, "y": 24.87705138},
    "W": {"x":  22.56585670, "y": 87.32219274},
    "Y": {"x":  38.42437789, "y": 37.86206471}
}

# プロット準備
plt.figure(figsize=(10, 10))
plt.axhline(0, color='gray', linestyle='--', linewidth=0.5)
plt.axvline(0, color='gray', linestyle='--', linewidth=0.5)

# アミノ酸ごとに色を付けて矢印描画
for i, (aa, vec) in enumerate(amino_vec.items()):
    x, y = vec["x"], vec["y"]
    color = cmap(i / len(amino_vec))  # カラーパレットをループ
    plt.arrow(0, 0, x, y, head_width=2, head_length=4, fc=color, ec=color, alpha=0.8)
    plt.text(x * 1.05, y * 1.05, aa, fontsize=12, ha='center', va='center', color="black")

# 描画設定
plt.title("ESM Embedding Amino Acid Vectors with Individual Colors")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.axis("equal")
plt.tight_layout()
plt.show()

# %% [markdown]
# # 埋め込みの平均ベクトルでTransformerを学習＆5分割交差検証
# - モデル：`esm-2`

# %% [markdown]
# ## 1. 必要ライブラリのインポート

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import numpy as np

model_name = "esm2"

# %% [markdown]
# ### 1.1 データセットの作成

# %%
class MeanEmbeddingDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.long)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx].unsqueeze(0), self.y[idx]

# %% [markdown]
# ### 1.2 Transformer分類モデル

# %%
import torch.nn as nn

class MeanEmbeddingTransformerClassifier(nn.Module):
    def __init__(self, input_dim=2560, hidden_dim=512, num_classes=5, num_heads=8, num_layers=2, dropout=0.1):
        super().__init__()
        self.linear_proj = nn.Linear(input_dim, hidden_dim)
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=hidden_dim, nhead=num_heads, batch_first=True, dropout=dropout
        )
        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
        self.fc = nn.Linear(hidden_dim, num_classes)

    def forward(self, x):
        x = self.linear_proj(x)
        x = self.transformer(x)
        x = x.mean(dim=1)
        return self.fc(x)

# %% [markdown]
# ## 2. データ読み込み

# %%
X = np.load(f"../data/embedding-vectors/{model_name}/mean_vectors.npy")
y = np.load(f"../data/embedding-vectors/{model_name}/labels.npy")

print("X.shape:", X.shape)
print("y.shape:", y.shape)
# Out:
# X.shape: (7716, 2560)
# y.shape: (7716,)

# %% [markdown]
# ## 3. 学習と評価（5分割交差検証）

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
import torch.optim as optim

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)  # 5分割交差検証

accuracies, precisions, recalls, f1_scores = [], [], [], []

# %%
for fold, (train_idx, val_idx) in enumerate(skf.split(X, y), 1):
    print(f"\033[34m[Fold {fold} / 5]\033[0m")

    train_ds = MeanEmbeddingDataset(X[train_idx], y[train_idx])
    val_ds = MeanEmbeddingDataset(X[val_idx], y[val_idx])

    train_loader = DataLoader(train_ds, batch_size=32, shuffle=True)
    val_loader = DataLoader(val_ds, batch_size=32)

    model = MeanEmbeddingTransformerClassifier().to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=1e-4)

    # --- 学習ループ ---
    for epoch in range(100):  # 調整可能
        model.train()
        total_loss = 0

        for xb, yb in train_loader:
            xb, yb = xb.to(device), yb.to(device)
            optimizer.zero_grad()
            out = model(xb)
            loss = criterion(out, yb)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        print(f"\033[36mEpoch {epoch + 1}, loss={total_loss/len(train_loader):.6f}\033[0m")

    # --- 評価 ---
    model.eval()
    y_true, y_pred = [], []

    with torch.no_grad():
        for xb, yb in val_loader:
            xb = xb.to(device)
            out = model(xb)
            preds = out.argmax(dim=1).cpu().numpy()
            y_pred.extend(preds)
            y_true.extend(yb.numpy())

    # --- 指標の計算 ---
    acc = accuracy_score(y_true, y_pred)
    prec = precision_score(y_true, y_pred, average="macro", zero_division=0)
    rec = recall_score(y_true, y_pred, average="macro", zero_division=0)
    f1 = f1_score(y_true, y_pred, average="macro")
    cm = confusion_matrix(y_true, y_pred)

    # --- 保存 ---
    accuracies.append(acc)
    precisions.append(prec)
    recalls.append(rec)
    f1_scores.append(f1)

    # --- 出力 ---
    print(f"\n\033[32mFold {fold} result:\033[0m")
    print(f"\033[92mAccuracy : {acc:.4f}\033[0m")
    print(f"\033[92mPrecision: {prec:.4f}\033[0m")
    print(f"\033[92mRecall   : {rec:.4f}\033[0m")
    print(f"\033[92mF1-score : {f1:.4f}\033[0m")
    print("\nConfusion Matrix:")
    print(cm)
    print("\nClassification Report:")
    print(classification_report(y_true, y_pred, zero_division=0, digits=4))

# === 平均結果 ===
print("\n\033[35m===== Cross-validation Summary =====\033[0m")
print(f"\033[95mMean Accuracy : {np.mean(accuracies):.4f} ± {np.std(accuracies):.4f}\033[0m")
print(f"\033[95mMean Precision: {np.mean(precisions):.4f} ± {np.std(precisions):.4f}\033[0m")
print(f"\033[95mMean Recall   : {np.mean(recalls):.4f} ± {np.std(recalls):.4f}\033[0m")
print(f"\033[95mMean F1-score : {np.mean(f1_scores):.4f} ± {np.std(f1_scores):.4f}\033[0m")
# Out:
# [Fold 1 / 5]
# Epoch 1, loss=0.610349
# Epoch 2, loss=0.474201
# Epoch 3, loss=0.425489
# Epoch 4, loss=0.399520
# Epoch 5, loss=0.387225
# Epoch 6, loss=0.369748
# Epoch 7, loss=0.368266
# Epoch 8, loss=0.352238
# Epoch 9, loss=0.355089
# Epoch 10, loss=0.347014
# Epoch 11, loss=0.339620
# Epoch 12, loss=0.334018
# Epoch 13, loss=0.332189
# Epoch 14, loss=0.328486
# Epoch 15, loss=0.333157
# Epoch 16, loss=0.321970
# Epoch 17, loss=0.324054
# Epoch 18, loss=0.327203
# Epoch 19, loss=0.321642
# Epoch 20, loss=0.329254
# Epoch 21, loss=0.314089
# Epoch 22, loss=0.309765
# Epoch 23, loss=0.311684
# Epoch 24, loss=0.310329
# Epoch 25, loss=0.313401
# Epoch 26, loss=0.312693
# Epoch 27, loss=0.307557
# Epoch 28, loss=0.307513
# Epoch 29, loss=0.310170
# Epoch 30, loss=0.304019
# Epoch 31, loss=0.306478
# Epoch 32, loss=0.303512
# Epoch 33, loss=0.300448
# Epoch 34, loss=0.298075
# Epoch 35, loss=0.302375
# Epoch 36, loss=0.294623
# Epoch 37, loss=0.296622
# Epoch 38, loss=0.297638
# Epoch 39, loss=0.294216
# Epoch 40, loss=0.300068
# Epoch 41, loss=0.301953
# Epoch 42, loss=0.300179
# Epoch 43, loss=0.293095
# Epoch 44, loss=0.294526
# Epoch 45, loss=0.288464
# Epoch 46, loss=0.288039
# Epoch 47, loss=0.293626
# Epoch 48, loss=0.292824
# Epoch 49, loss=0.291323
# Epoch 50, loss=0.293829
# Epoch 51, loss=0.293249
# Epoch 52, loss=0.286187
# Epoch 53, loss=0.302485
# Epoch 54, loss=0.285782
# Epoch 55, loss=0.283763
# Epoch 56, loss=0.289614
# Epoch 57, loss=0.300515
# Epoch 58, loss=0.291470
# Epoch 59, loss=0.292043
# Epoch 60, loss=0.282327
# Epoch 61, loss=0.286307
# Epoch 62, loss=0.286515
# Epoch 63, loss=0.287195
# Epoch 64, loss=0.283888
# Epoch 65, loss=0.284275
# Epoch 66, loss=0.284436
# Epoch 67, loss=0.282323
# Epoch 68, loss=0.284413
# Epoch 69, loss=0.284340
# Epoch 70, loss=0.283417
# Epoch 71, loss=0.288872
# Epoch 72, loss=0.285112
# Epoch 73, loss=0.278653
# Epoch 74, loss=0.287396
# Epoch 75, loss=0.275877
# Epoch 76, loss=0.279903
# Epoch 77, loss=0.276433
# Epoch 78, loss=0.279397
# Epoch 79, loss=0.282588
# Epoch 80, loss=0.279133
# Epoch 81, loss=0.281650
# Epoch 82, loss=0.279368
# Epoch 83, loss=0.278325
# Epoch 84, loss=0.278586
# Epoch 85, loss=0.278638
# Epoch 86, loss=0.276231
# Epoch 87, loss=0.273786
# Epoch 88, loss=0.280809
# Epoch 89, loss=0.286677
# Epoch 90, loss=0.274186
# Epoch 91, loss=0.273562
# Epoch 92, loss=0.278910
# Epoch 93, loss=0.273200
# Epoch 94, loss=0.276246
# Epoch 95, loss=0.271660
# Epoch 96, loss=0.272076
# Epoch 97, loss=0.272957
# Epoch 98, loss=0.275217
# Epoch 99, loss=0.272333
# Epoch 100, loss=0.286738
#
# Fold 1 result:
# Accuracy : 0.8290
# Precision: 0.4281
# Recall   : 0.3841
# F1-score : 0.3798
#
# Confusion Matrix:
# [[913  11 137   0   0]
#  [ 61  13  17   0   0]
#  [ 32   0 354   0   0]
#  [  3   0   0   0   0]
#  [  3   0   0   0   0]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.9022    0.8605    0.8808      1061
#            1     0.5417    0.1429    0.2261        91
#            2     0.6969    0.9171    0.7919       386
#            3     0.0000    0.0000    0.0000         3
#            4     0.0000    0.0000    0.0000         3
#
#     accuracy                         0.8290      1544
#    macro avg     0.4281    0.3841    0.3798      1544
# weighted avg     0.8261    0.8290    0.8166      1544
#
# [Fold 2 / 5]
# Epoch 1, loss=0.601774
# Epoch 2, loss=0.479172
# Epoch 3, loss=0.431448
# Epoch 4, loss=0.405795
# Epoch 5, loss=0.390284
# Epoch 6, loss=0.376684
# Epoch 7, loss=0.366664
# Epoch 8, loss=0.363816
# Epoch 9, loss=0.358466
# Epoch 10, loss=0.356825
# Epoch 11, loss=0.347664
# Epoch 12, loss=0.345321
# Epoch 13, loss=0.348151
# Epoch 14, loss=0.333685
# Epoch 15, loss=0.338858
# Epoch 16, loss=0.339189
# Epoch 17, loss=0.327795
# Epoch 18, loss=0.323066
# Epoch 19, loss=0.322787
# Epoch 20, loss=0.322738
# Epoch 21, loss=0.322835
# Epoch 22, loss=0.331801
# Epoch 23, loss=0.319589
# Epoch 24, loss=0.317723
# Epoch 25, loss=0.316507
# Epoch 26, loss=0.312596
# Epoch 27, loss=0.315308
# Epoch 28, loss=0.313908
# Epoch 29, loss=0.308652
# Epoch 30, loss=0.307556
# Epoch 31, loss=0.308202
# Epoch 32, loss=0.305384
# Epoch 33, loss=0.306469
# Epoch 34, loss=0.306863
# Epoch 35, loss=0.303313
# Epoch 36, loss=0.316725
# Epoch 37, loss=0.303210
# Epoch 38, loss=0.299682
# Epoch 39, loss=0.298453
# Epoch 40, loss=0.299431
# Epoch 41, loss=0.299542
# Epoch 42, loss=0.303852
# Epoch 43, loss=0.299122
# Epoch 44, loss=0.298355
# Epoch 45, loss=0.297641
# Epoch 46, loss=0.314106
# Epoch 47, loss=0.295657
# Epoch 48, loss=0.294111
# Epoch 49, loss=0.297607
# Epoch 50, loss=0.303563
# Epoch 51, loss=0.293258
# Epoch 52, loss=0.293105
# Epoch 53, loss=0.292029
# Epoch 54, loss=0.298731
# Epoch 55, loss=0.295687
# Epoch 56, loss=0.289145
# Epoch 57, loss=0.294520
# Epoch 58, loss=0.297647
# Epoch 59, loss=0.290312
# Epoch 60, loss=0.288305
# Epoch 61, loss=0.291019
# Epoch 62, loss=0.287240
# Epoch 63, loss=0.296056
# Epoch 64, loss=0.289487
# Epoch 65, loss=0.287128
# Epoch 66, loss=0.288648
# Epoch 67, loss=0.293353
# Epoch 68, loss=0.293805
# Epoch 69, loss=0.287144
# Epoch 70, loss=0.289321
# Epoch 71, loss=0.289747
# Epoch 72, loss=0.285179
# Epoch 73, loss=0.284525
# Epoch 74, loss=0.283511
# Epoch 75, loss=0.286702
# Epoch 76, loss=0.285744
# Epoch 77, loss=0.287643
# Epoch 78, loss=0.290207
# Epoch 79, loss=0.281645
# Epoch 80, loss=0.286960
# Epoch 81, loss=0.282902
# Epoch 82, loss=0.279362
# Epoch 83, loss=0.287430
# Epoch 84, loss=0.286284
# Epoch 85, loss=0.282439
# Epoch 86, loss=0.281723
# Epoch 87, loss=0.286046
# Epoch 88, loss=0.279869
# Epoch 89, loss=0.280568
# Epoch 90, loss=0.280026
# Epoch 91, loss=0.276978
# Epoch 92, loss=0.282660
# Epoch 93, loss=0.281227
# Epoch 94, loss=0.284377
# Epoch 95, loss=0.278344
# Epoch 96, loss=0.278126
# Epoch 97, loss=0.275150
# Epoch 98, loss=0.278942
# Epoch 99, loss=0.280024
# Epoch 100, loss=0.279852
#
# Fold 2 result:
# Accuracy : 0.8548
# Precision: 0.4794
# Recall   : 0.3973
# F1-score : 0.4046
#
# Confusion Matrix:
# [[956   5 100   0   0]
#  [ 62  17  10   0   1]
#  [ 39   1 346   0   0]
#  [  2   0   0   0   0]
#  [  4   0   0   0   0]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.8993    0.9010    0.9002      1061
#            1     0.7391    0.1889    0.3009        90
#            2     0.7588    0.8964    0.8219       386
#            3     0.0000    0.0000    0.0000         2
#            4     0.0000    0.0000    0.0000         4
#
#     accuracy                         0.8548      1543
#    macro avg     0.4794    0.3973    0.4046      1543
# weighted avg     0.8513    0.8548    0.8421      1543
#
# [Fold 3 / 5]
# Epoch 1, loss=0.607019
# Epoch 2, loss=0.487500
# Epoch 3, loss=0.421183
# Epoch 4, loss=0.404316
# Epoch 5, loss=0.389021
# Epoch 6, loss=0.378707
# Epoch 7, loss=0.361959
# Epoch 8, loss=0.367286
# Epoch 9, loss=0.354054
# Epoch 10, loss=0.354529
# Epoch 11, loss=0.343966
# Epoch 12, loss=0.344056
# Epoch 13, loss=0.334113
# Epoch 14, loss=0.335336
# Epoch 15, loss=0.334670
# Epoch 16, loss=0.323307
# Epoch 17, loss=0.329635
# Epoch 18, loss=0.326027
# Epoch 19, loss=0.325706
# Epoch 20, loss=0.330092
# Epoch 21, loss=0.325582
# Epoch 22, loss=0.318926
# Epoch 23, loss=0.312308
# Epoch 24, loss=0.316668
# Epoch 25, loss=0.315185
# Epoch 26, loss=0.316512
# Epoch 27, loss=0.311628
# Epoch 28, loss=0.306781
# Epoch 29, loss=0.307738
# Epoch 30, loss=0.321995
# Epoch 31, loss=0.316028
# Epoch 32, loss=0.304453
# Epoch 33, loss=0.305266
# Epoch 34, loss=0.301883
# Epoch 35, loss=0.299038
# Epoch 36, loss=0.301218
# Epoch 37, loss=0.305702
# Epoch 38, loss=0.304035
# Epoch 39, loss=0.301425
# Epoch 40, loss=0.302865
# Epoch 41, loss=0.294610
# Epoch 42, loss=0.303191
# Epoch 43, loss=0.302263
# Epoch 44, loss=0.298472
# Epoch 45, loss=0.302013
# Epoch 46, loss=0.298800
# Epoch 47, loss=0.298591
# Epoch 48, loss=0.300900
# Epoch 49, loss=0.298259
# Epoch 50, loss=0.292195
# Epoch 51, loss=0.294410
# Epoch 52, loss=0.295752
# Epoch 53, loss=0.301289
# Epoch 54, loss=0.295550
# Epoch 55, loss=0.294147
# Epoch 56, loss=0.289421
# Epoch 57, loss=0.291203
# Epoch 58, loss=0.286327
# Epoch 59, loss=0.290212
# Epoch 60, loss=0.291586
# Epoch 61, loss=0.291671
# Epoch 62, loss=0.285718
# Epoch 63, loss=0.288949
# Epoch 64, loss=0.291224
# Epoch 65, loss=0.289958
# Epoch 66, loss=0.287619
# Epoch 67, loss=0.283685
# Epoch 68, loss=0.285550
# Epoch 69, loss=0.284295
# Epoch 70, loss=0.296189
# Epoch 71, loss=0.290123
# Epoch 72, loss=0.286703
# Epoch 73, loss=0.284110
# Epoch 74, loss=0.285425
# Epoch 75, loss=0.287380
# Epoch 76, loss=0.282889
# Epoch 77, loss=0.285696
# Epoch 78, loss=0.283247
# Epoch 79, loss=0.285898
# Epoch 80, loss=0.286292
# Epoch 81, loss=0.282057
# Epoch 82, loss=0.282210
# Epoch 83, loss=0.291116
# Epoch 84, loss=0.286105
# Epoch 85, loss=0.281661
# Epoch 86, loss=0.282334
# Epoch 87, loss=0.277764
# Epoch 88, loss=0.278988
# Epoch 89, loss=0.279362
# Epoch 90, loss=0.279158
# Epoch 91, loss=0.281013
# Epoch 92, loss=0.280689
# Epoch 93, loss=0.275942
# Epoch 94, loss=0.277620
# Epoch 95, loss=0.278643
# Epoch 96, loss=0.272800
# Epoch 97, loss=0.281049
# Epoch 98, loss=0.276866
# Epoch 99, loss=0.276868
# Epoch 100, loss=0.274147
#
# Fold 3 result:
# Accuracy : 0.8458
# Precision: 0.4423
# Recall   : 0.3887
# F1-score : 0.3936
#
# Confusion Matrix:
# [[954   8  98   0   0]
#  [ 58  16  17   0   0]
#  [ 47   4 335   0   0]
#  [  2   0   0   0   0]
#  [  4   0   0   0   0]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.8958    0.9000    0.8979      1060
#            1     0.5714    0.1758    0.2689        91
#            2     0.7444    0.8679    0.8014       386
#            3     0.0000    0.0000    0.0000         2
#            4     0.0000    0.0000    0.0000         4
#
#     accuracy                         0.8458      1543
#    macro avg     0.4423    0.3887    0.3936      1543
# weighted avg     0.8353    0.8458    0.8332      1543
#
# [Fold 4 / 5]
# Epoch 1, loss=0.597186
# Epoch 2, loss=0.461243
# Epoch 3, loss=0.419417
# Epoch 4, loss=0.388931
# Epoch 5, loss=0.372079
# Epoch 6, loss=0.373739
# Epoch 7, loss=0.361970
# Epoch 8, loss=0.351433
# Epoch 9, loss=0.341932
# Epoch 10, loss=0.345065
# Epoch 11, loss=0.338861
# Epoch 12, loss=0.339297
# Epoch 13, loss=0.336500
# Epoch 14, loss=0.328096
# Epoch 15, loss=0.327902
# Epoch 16, loss=0.329606
# Epoch 17, loss=0.323913
# Epoch 18, loss=0.319863
# Epoch 19, loss=0.318958
# Epoch 20, loss=0.317761
# Epoch 21, loss=0.313116
# Epoch 22, loss=0.317827
# Epoch 23, loss=0.313358
# Epoch 24, loss=0.320395
# Epoch 25, loss=0.317914
# Epoch 26, loss=0.311317
# Epoch 27, loss=0.306564
# Epoch 28, loss=0.313367
# Epoch 29, loss=0.305456
# Epoch 30, loss=0.303623
# Epoch 31, loss=0.306611
# Epoch 32, loss=0.301688
# Epoch 33, loss=0.300892
# Epoch 34, loss=0.297514
# Epoch 35, loss=0.298689
# Epoch 36, loss=0.300385
# Epoch 37, loss=0.301613
# Epoch 38, loss=0.302097
# Epoch 39, loss=0.302290
# Epoch 40, loss=0.299330
# Epoch 41, loss=0.298687
# Epoch 42, loss=0.297019
# Epoch 43, loss=0.293538
# Epoch 44, loss=0.300738
# Epoch 45, loss=0.295076
# Epoch 46, loss=0.293417
# Epoch 47, loss=0.296911
# Epoch 48, loss=0.297656
# Epoch 49, loss=0.298103
# Epoch 50, loss=0.293002
# Epoch 51, loss=0.291331
# Epoch 52, loss=0.290054
# Epoch 53, loss=0.289106
# Epoch 54, loss=0.294972
# Epoch 55, loss=0.285879
# Epoch 56, loss=0.297624
# Epoch 57, loss=0.285140
# Epoch 58, loss=0.286384
# Epoch 59, loss=0.285940
# Epoch 60, loss=0.290641
# Epoch 61, loss=0.284603
# Epoch 62, loss=0.296056
# Epoch 63, loss=0.286448
# Epoch 64, loss=0.283182
# Epoch 65, loss=0.290411
# Epoch 66, loss=0.286398
# Epoch 67, loss=0.281906
# Epoch 68, loss=0.282298
# Epoch 69, loss=0.289386
# Epoch 70, loss=0.284507
# Epoch 71, loss=0.284097
# Epoch 72, loss=0.290228
# Epoch 73, loss=0.283605
# Epoch 74, loss=0.287463
# Epoch 75, loss=0.289081
# Epoch 76, loss=0.279007
# Epoch 77, loss=0.282959
# Epoch 78, loss=0.279688
# Epoch 79, loss=0.284528
# Epoch 80, loss=0.277371
# Epoch 81, loss=0.277028
# Epoch 82, loss=0.281934
# Epoch 83, loss=0.279777
# Epoch 84, loss=0.285727
# Epoch 85, loss=0.281197
# Epoch 86, loss=0.279476
# Epoch 87, loss=0.275876
# Epoch 88, loss=0.276766
# Epoch 89, loss=0.274195
# Epoch 90, loss=0.274113
# Epoch 91, loss=0.276537
# Epoch 92, loss=0.274304
# Epoch 93, loss=0.278147
# Epoch 94, loss=0.279814
# Epoch 95, loss=0.276957
# Epoch 96, loss=0.280400
# Epoch 97, loss=0.277379
# Epoch 98, loss=0.276292
# Epoch 99, loss=0.279148
# Epoch 100, loss=0.278951
#
# Fold 4 result:
# Accuracy : 0.8192
# Precision: 0.4763
# Recall   : 0.3891
# F1-score : 0.3911
#
# Confusion Matrix:
# [[900   3 157   0   0]
#  [ 54  18  19   0   0]
#  [ 38   1 346   0   0]
#  [  2   0   1   0   0]
#  [  4   0   0   0   0]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.9018    0.8491    0.8746      1060
#            1     0.8182    0.1978    0.3186        91
#            2     0.6616    0.8987    0.7621       385
#            3     0.0000    0.0000    0.0000         3
#            4     0.0000    0.0000    0.0000         4
#
#     accuracy                         0.8192      1543
#    macro avg     0.4763    0.3891    0.3911      1543
# weighted avg     0.8328    0.8192    0.8098      1543
#
# [Fold 5 / 5]
# Epoch 1, loss=0.598866
# Epoch 2, loss=0.490218
# Epoch 3, loss=0.426470
# Epoch 4, loss=0.403191
# Epoch 5, loss=0.386368
# Epoch 6, loss=0.374740
# Epoch 7, loss=0.363133
# Epoch 8, loss=0.361058
# Epoch 9, loss=0.358723
# Epoch 10, loss=0.359056
# Epoch 11, loss=0.346550
# Epoch 12, loss=0.350420
# Epoch 13, loss=0.334201
# Epoch 14, loss=0.328208
# Epoch 15, loss=0.332975
# Epoch 16, loss=0.328813
# Epoch 17, loss=0.323820
# Epoch 18, loss=0.320581
# Epoch 19, loss=0.319346
# Epoch 20, loss=0.314837
# Epoch 21, loss=0.324278
# Epoch 22, loss=0.323374
# Epoch 23, loss=0.312735
# Epoch 24, loss=0.314473
# Epoch 25, loss=0.309791
# Epoch 26, loss=0.310019
# Epoch 27, loss=0.305429
# Epoch 28, loss=0.308444
# Epoch 29, loss=0.301110
# Epoch 30, loss=0.308192
# Epoch 31, loss=0.303614
# Epoch 32, loss=0.302164
# Epoch 33, loss=0.304783
# Epoch 34, loss=0.300821
# Epoch 35, loss=0.302298
# Epoch 36, loss=0.305003
# Epoch 37, loss=0.295834
# Epoch 38, loss=0.297943
# Epoch 39, loss=0.295969
# Epoch 40, loss=0.295704
# Epoch 41, loss=0.296906
# Epoch 42, loss=0.294646
# Epoch 43, loss=0.294971
# Epoch 44, loss=0.296136
# Epoch 45, loss=0.293834
# Epoch 46, loss=0.297313
# Epoch 47, loss=0.289815
# Epoch 48, loss=0.293551
# Epoch 49, loss=0.294604
# Epoch 50, loss=0.293903
# Epoch 51, loss=0.291320
# Epoch 52, loss=0.294256
# Epoch 53, loss=0.292334
# Epoch 54, loss=0.289404
# Epoch 55, loss=0.305578
# Epoch 56, loss=0.284589
# Epoch 57, loss=0.290225
# Epoch 58, loss=0.292957
# Epoch 59, loss=0.297005
# Epoch 60, loss=0.288051
# Epoch 61, loss=0.285946
# Epoch 62, loss=0.283868
# Epoch 63, loss=0.281820
# Epoch 64, loss=0.284873
# Epoch 65, loss=0.285509
# Epoch 66, loss=0.290159
# Epoch 67, loss=0.288827
# Epoch 68, loss=0.286481
# Epoch 69, loss=0.282468
# Epoch 70, loss=0.280073
# Epoch 71, loss=0.287699
# Epoch 72, loss=0.281962
# Epoch 73, loss=0.278294
# Epoch 74, loss=0.283544
# Epoch 75, loss=0.284303
# Epoch 76, loss=0.283146
# Epoch 77, loss=0.277063
# Epoch 78, loss=0.284420
# Epoch 79, loss=0.282653
# Epoch 80, loss=0.283693
# Epoch 81, loss=0.279739
# Epoch 82, loss=0.286486
# Epoch 83, loss=0.281590
# Epoch 84, loss=0.277817
# Epoch 85, loss=0.281700
# Epoch 86, loss=0.276045
# Epoch 87, loss=0.283290
# Epoch 88, loss=0.276546
# Epoch 89, loss=0.286111
# Epoch 90, loss=0.275829
# Epoch 91, loss=0.274226
# Epoch 92, loss=0.270853
# Epoch 93, loss=0.275147
# Epoch 94, loss=0.273853
# Epoch 95, loss=0.281908
# Epoch 96, loss=0.282267
# Epoch 97, loss=0.272018
# Epoch 98, loss=0.274754
# Epoch 99, loss=0.274375
# Epoch 100, loss=0.278534
#
# Fold 5 result:
# Accuracy : 0.8283
# Precision: 0.4473
# Recall   : 0.3777
# F1-score : 0.3820
#
# Confusion Matrix:
# [[935   8 117   0   0]
#  [ 68  14   9   0   0]
#  [ 57   0 329   0   0]
#  [  3   0   0   0   0]
#  [  3   0   0   0   0]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.8771    0.8821    0.8796      1060
#            1     0.6364    0.1538    0.2478        91
#            2     0.7231    0.8523    0.7824       386
#            3     0.0000    0.0000    0.0000         3
#            4     0.0000    0.0000    0.0000         3
#
#     accuracy                         0.8283      1543
#    macro avg     0.4473    0.3777    0.3820      1543
# weighted avg     0.8210    0.8283    0.8146      1543
#
#
# ===== Cross-validation Summary =====
# Mean Accuracy : 0.8354 ± 0.0130
# Mean Precision: 0.4547 ± 0.0200
# Mean Recall   : 0.3874 ± 0.0064
# Mean F1-score : 0.3902 ± 0.0089
